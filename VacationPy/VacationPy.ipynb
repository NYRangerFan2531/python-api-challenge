# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# import pritty print for testing
from pprint import pprint

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0              crane  31.3974 -102.3501     16.02        19
# 1        1  port-aux-francais -49.3500   70.2167      6.37        87
# 2        2             mahina -17.5065 -149.4890     29.87        70
# 3        3            bazarak  35.3129   69.5152     -2.18        77
# 4        4              conde  -7.2597  -34.9075     26.70        78
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        3.31      US  1702759399
# 1          97       11.11      TF  1702759386
# 2          20        4.12      PF  1702759211
# 3          26        4.56      AF  1702759461
# 4           0        6.17      BR  1702759461

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot

map_plot = city_data_df.hvplot.points(
    "Lng", "Lat",
    size = "Humidity",
    color = "City",
    xlabel = "Longitude",
    ylabel = "Latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 0.8,
    coastline=True,
    alpha=0.5,
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I     :Tiles   [x,y]
#    .Points.I    :Points   [Lng,Lat]   (City,Humidity)
#    .Coastline.I :Feature   [Longitude,Latitude]

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_ideal_df = city_data_df[
                            (city_data_df['Max Temp'] < 27 ) &
                            (city_data_df['Max Temp'] > 21 ) &
                            (city_data_df['Wind Speed'] < 4.5 ) & 
                            (city_data_df['Cloudiness'] == 0)
                            ]

# Drop any rows with null values
city_ideal_df.dropna()

# Display sample data
city_ideal_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 80        80                 fortuna  40.5982 -124.1573     21.63        47
# 120      120          guerrero negro  27.9769 -114.0611     23.70        28
# 166      166            saint-pierre -21.3393   55.4781     24.82        73
# 218      218              el granada  37.5027 -122.4694     21.80        45
# 266      266  hawaiian paradise park  19.5933 -154.9731     23.83        86
# 307      307             nova vicosa -17.8919  -39.3719     25.74        70
# 416      416               ar ruways  24.1103   52.7306     21.51        67
# 442      442                  lompoc  34.6391 -120.4579     25.99        33
#
#      Cloudiness  Wind Speed Country        Date
# 80            0        3.13      US  1702759430
# 120           0        3.94      MX  1702759471
# 166           0        2.06      RE  1702759415
# 218           0        2.57      US  1702759411
# 266           0        4.12      US  1702759390
# 307           0        3.75      BR  1702759487
# 416           0        2.99      AE  1702759495
# 442           0        2.06      US  1702759424

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
hotel_df  =  city_ideal_df.copy()
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 80        80                 fortuna  40.5982 -124.1573     21.63        47
# 120      120          guerrero negro  27.9769 -114.0611     23.70        28
# 166      166            saint-pierre -21.3393   55.4781     24.82        73
# 218      218              el granada  37.5027 -122.4694     21.80        45
# 266      266  hawaiian paradise park  19.5933 -154.9731     23.83        86
# 307      307             nova vicosa -17.8919  -39.3719     25.74        70
# 416      416               ar ruways  24.1103   52.7306     21.51        67
# 442      442                  lompoc  34.6391 -120.4579     25.99        33
#
#      Cloudiness  Wind Speed Country        Date Hotel Name
# 80            0        3.13      US  1702759430
# 120           0        3.94      MX  1702759471
# 166           0        2.06      RE  1702759415
# 218           0        2.57      US  1702759411
# 266           0        4.12      US  1702759390
# 307           0        3.75      BR  1702759487
# 416           0        2.99      AE  1702759495
# 442           0        2.06      US  1702759424

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df  =  city_ideal_df.copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 80        80                 fortuna  40.5982 -124.1573     21.63        47
# 120      120          guerrero negro  27.9769 -114.0611     23.70        28
# 166      166            saint-pierre -21.3393   55.4781     24.82        73
# 218      218              el granada  37.5027 -122.4694     21.80        45
# 266      266  hawaiian paradise park  19.5933 -154.9731     23.83        86
# 307      307             nova vicosa -17.8919  -39.3719     25.74        70
# 416      416               ar ruways  24.1103   52.7306     21.51        67
# 442      442                  lompoc  34.6391 -120.4579     25.99        33
#
#      Cloudiness  Wind Speed Country        Date Hotel Name
# 80            0        3.13      US  1702759430
# 120           0        3.94      MX  1702759471
# 166           0        2.06      RE  1702759415
# 218           0        2.57      US  1702759411
# 266           0        4.12      US  1702759390
# 307           0        3.75      BR  1702759487
# 416           0        2.99      AE  1702759495
# 442           0        2.06      US  1702759424

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "filter": "",
    "bias": "",
    "categories": "accommodation.hotel",
    "distance": radius,  
    "apiKey": geoapify_key
}


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index,"Lat"]
    longitude = hotel_df.loc[index,"Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty and Convert the API response to JSON format
    name_address = requests.get(base_url, params=params).json()


    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "(No hotel found)"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# guerrero negro - nearest hotel: Plaza sal paraiso
# saint-pierre - nearest hotel: Tropic Hotel
# el granada - nearest hotel: Beach House
# hawaiian paradise park - nearest hotel: (No hotel found)
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# ar ruways - nearest hotel: (No hotel found)
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 80        80                 fortuna  40.5982 -124.1573     21.63        47
# 120      120          guerrero negro  27.9769 -114.0611     23.70        28
# 166      166            saint-pierre -21.3393   55.4781     24.82        73
# 218      218              el granada  37.5027 -122.4694     21.80        45
# 266      266  hawaiian paradise park  19.5933 -154.9731     23.83        86
# 307      307             nova vicosa -17.8919  -39.3719     25.74        70
# 416      416               ar ruways  24.1103   52.7306     21.51        67
# 442      442                  lompoc  34.6391 -120.4579     25.99        33
#
#      Cloudiness  Wind Speed Country        Date  \
# 80            0        3.13      US  1702759430
# 120           0        3.94      MX  1702759471
# 166           0        2.06      RE  1702759415
# 218           0        2.57      US  1702759411
# 266           0        4.12      US  1702759390
# 307           0        3.75      BR  1702759487
# 416           0        2.99      AE  1702759495
# 442           0        2.06      US  1702759424
#
#                                         Hotel Name
# 80            Comfort Inn & Suites Redwood Country
# 120                              Plaza sal paraiso
# 166                                   Tropic Hotel
# 218                                    Beach House
# 266                               (No hotel found)
# 307                        Pousada Pontal da Barra
# 416                               (No hotel found)
# 442  Embassy Suites by Hilton Lompoc Central Coast

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot2 = hotel_df.hvplot.points(
    "Lng", "Lat",
    size = "Humidity",
    color = "City",
    xlabel = "Longitude",
    ylabel = "Latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 0.8,
    coastline=True,
    alpha=0.5,
    hover_cols = ["Hotel Name","Country"]
)

# Display the map
map_plot2
# Out:
# :Overlay
#    .Tiles.I     :Tiles   [x,y]
#    .Points.I    :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
#    .Coastline.I :Feature   [Longitude,Latitude]
